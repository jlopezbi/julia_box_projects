# %%
Pkg.add("NBInclude")
using NBInclude
nbinclude("Logistic_Map.ipynb")
using LogisticMap
# Out:
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of NBInclude
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# WARNING: replacing module LogisticMap
# WARNING: ignoring conflicting import of LogisticMap.logistic_loop into Main

# %%
using PyPlot

# %%
x_o = 0.2
x_lim = [0.47, 0.48]
r_step = .00001
r_start = 3.569 + .00085
r_end = 3.569 + .00095
iterates = 1000
discard = 800
#R = r_start:r_step:r_end;
R = linspace(r_start, r_end, 300);

# %%
figure(figsize=(10,8))
for i = 1:size(R,1)
    f = logistic_loop(n=iterates, x_0=x_o, r=R[i])[discard:end]
    r_vec = ones(size(f,1),1)*R[i]
    plot(r_vec, f, linestyle="", marker="o", markersize=.1, color="k")
end
ylim(x_lim)
xlabel("r -- parameter in logistic map")
ylabel("x -- final values of logistic map");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f32c4c33610>)

# %%
function number_unique_vector(vector)
    #note unique relies on Base.isequal, 
    #it appears to care about 14 decimal places!
    u = unique(vector)
    return size(u,1)
end
# Out:
# number_unique_vector (generic function with 1 method)

# %%
function round_decimals(vector, digits)
    for i in eachindex(vector)
        vector[i] = round(vector[i], digits)
    end
    return vector
end
# Out:
# round_decimals (generic function with 1 method)

# %%
iterates = convert(Int64, 1e6)
discard = convert(Int64, 9.9e5)
m = logistic_loop(n=iterates, x_0=x_o, r = 2.9999)[discard:end];
m_rounded = round_decimals(m, 8)
number_unique_vector(m)
# Out:
# UndefVarError: number_unique_vector not defined
#
#  in include_string(::String, ::String) at ./loading.jl:441

# %%
l_map(R) = logistic_loop(n=iterates, x_0=x_o, r=R)
# Out:
# l_map (generic function with 1 method)

# %%
function iterative_map_unique(R, func)
    #func is a function that iterates a 1D map n times, starting at x_0,
    #with one parameter..hmm should be multiple parameters
    iterates = convert(Int64, 5e5)
    discard = convert(Int64, 4.99e5)
    m = func(n=iterates, x_0=x_o, r = R)[discard:end]
    m_rounded = round_decimals(m, 8)
    number_unique_vector(m)
end
# Out:
# WARNING: Method definition iterative_map_unique(Any, Any) in module Main at In[253]:4 overwritten at In[259]:4.
# iterative_map_unique (generic function with 1 method)

# %%
g(R) = iterative_map_unique(R, logistic_loop)
# Out:
# WARNING: Method definition g(Any) in module Main at In[254]:1 overwritten at In[260]:1.
# g (generic function with 1 method)

# %%
function find_bifurcation_point(func, low, high, tol, ;max_iter=1000)
    # func -- function for that take paramter and finds n_unique iterates
    # high, low -- start value for a parameter of the map
    # tol -- when diff. between high and low is at or below thresh
    #           it is considered to b the bifurcation point.
    # Uses Bisection method.. 
    # BEWARE! this funciton breaks in the special case where high and low
    # are close to symmetric about the bifurcation point. For now simply 
    # offset high and low slightely to remove error. Would be good to make robust
    # algorithm that squeezes Bif. pnt in the middle.
    low, high = sort([high, low]) #incase improper high/low
    n_high = func(high)
    n_low = func(low)
    println("n_low: $n_low, n_high: $n_high")
    i = 0
    while high-low > tol
        i+=1
        print(".")
        center = ( high + low ) / 2.0
        n_unique = func(center)
        if n_unique  == n_low
            low = center
        elseif n_unique == n_high
            high = center
        elseif n_unique > n_high
            #this is the case where the transient has still not
            #died out!
            print("ERROR! Influence of transient too high: n_unque greater than n_high")
            break
        elseif n_unique < n_low
            print("Error! found n_unique lower than initial low param")
            break
        elseif low > high
            print("ERROR! low is greater than high")
            break
        elseif i > max_iter
            print("hit max iters")
            break
        end
    end
    println("exit, hit tol")
    return low, high
end
# Out:
# WARNING: Method definition find_bifurcation_point(Any, Any, Any, Any) in module Main at In[256]:10 overwritten at In[262]:10.
# WARNING: Method definition #find_bifurcation_point(Array{Any, 1}, Main.#find_bifurcation_point, Any, Any, Any, Any) in module Main overwritten.
# find_bifurcation_point (generic function with 1 method)

# %%
find_bifurcation_point(g, 3.569 + .000881, 3.569 + .000921, 1e-10)
# Out:
# n_low: 64, n_high: 128
# ...

# %%
sum(ans)/size(ans,1)
# Out:
# 3.56989115625
